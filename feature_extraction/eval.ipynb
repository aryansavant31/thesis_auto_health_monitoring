# %%
import os, sys

ROOT_DIR = os.path.dirname(os.getcwd())
sys.path.insert(0, ROOT_DIR) if ROOT_DIR not in sys.path else None

# %% [markdown]
# ## Load data

# %%
from ranking_utils.data_adapter import DataAdapter
from data.config import DataConfig

data_config = DataConfig(run_type="custom_test")
data_adapter = DataAdapter(data_config)

Calc_0, Calc_FFT, fftFreq = data_adapter.get_dictionaries()
# Out:
# Total samples: 12168, Desired samples: 608, Remainder samples: 11560
# Data shape: torch.Size([600, 1, 500, 1])
# Labels shape: torch.Size([600])

# %% [markdown]
# ### Get rank log path

# %%
from settings.manager import FeatureRankingManager
rank_config = FeatureRankingManager(data_config)

rank_config.perf_version = 1
rank_path = rank_config.get_ranking_log_path()

# save ranking id for later tree visualization
rank_config.save_ranking_id()

print(f"Ranking path: {rank_path}")
# Out:
# Ranking id saved to c:\Aryan_Savant\Thesis_Projects\my_work\AFD_thesis\feature_extraction\logs\bearing\cwru\scene_1\(gearbox)\(gearbox)_perf_1\ranks_[a=0.5].
# Ranking path: c:\Aryan_Savant\Thesis_Projects\my_work\AFD_thesis\feature_extraction\logs\bearing\cwru\scene_1\(gearbox)\(gearbox)_perf_1\ranks_[a=0.5]

# %% [markdown]
# ## Final ranking

# %%
from ranking_utils.final_ranking import FinalFeatureRanking

final_ranking = FinalFeatureRanking(rank_path)

# %% [markdown]
# ### Feature correlation

# %%
final_ranking.get_correlation_matrix(Calc_0)

# %% [markdown]
# ### Final ranking list

# %%
final_ranking.get_final_ranking(rank_config.alpha)
# Out:
# Final ranking for time features (ranks_[a=0.5], (gearbox)_perf_1):
# -----------------------------------------------------------------
# impulse_factor: 0.0756
# eo: 0.0864
# skewness: 0.0949
# fifth_moment_normalized: 0.1078
# mean_deviation_ratio: 0.1499
# mean: 0.1511
# zero_crossing_rate: 0.2505
# pulse_index: 0.2596
# fifth_moment: 0.3251
# wilson_amplitude: 0.4833
# crest_factor: 0.5731
# clearance_factor: 0.5765
# margin_index: 0.5765
# latitude_factor: 0.5765
# kurtosis: 0.5919
# shape_factor: 0.6007
# std_deviation_index: 0.6088
# waveform_indicator: 0.7317
# normalized_std: 0.7402
# hist_lower_bound: 0.7942
# min: 0.7942
# log_log_ratio: 0.8127
# sixth_moment: 0.8301
# difference_variance: 0.8418
# variance: 0.8446
# mean_abs_modif2: 0.8629
# peak_value: 0.8648
# max: 0.8662
# hist_upper_bound: 0.8662
# peak_to_peak: 0.8667
# mean_abs_modif1: 0.8668
# std: 0.8669
# rms: 0.8669
# mean_abs: 0.8675
# sq_root_abs: 0.8675
# waveform_length: 0.9113
# energy: 0.9588
#
# Final ranking for frequency features (ranks_[a=0.5], (gearbox)_perf_1):
# -----------------------------------------------------------------
# meanf: nan
# variancef: nan
# skewnessf: nan
# kurtosisf: nan
# central_freq: nan
# stdf: nan
# rmsf: nan
# spectral_spread: nan
# spectral_entropy: nan
# total_power: nan
# median_freq: nan
# pkf: nan
# first_spectral_moment: nan
# second_spectral_moment: nan
# third_spectral_moment: nan
# fourth_spectral_moment: nan
# vcf: nan
# frequency_ratio: nan
# hsc: nan
# spectral_flux: nan
# rolloff_frequency_90: nan
# rolloff_frequency_85: nan
# rolloff_frequency_75: nan
# rolloff_frequency_95: nan
# upper_limit_harmonicity: nan
