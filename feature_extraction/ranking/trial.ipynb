# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))

# %%
from data_adapter import DataAdapter

adapter = DataAdapter()

time_data, freq_amp, freq_bins, labels = adapter.load_all_data()
# Out:
# Postprocessed data shape: torch.Size([7313, 500, 1]), Original shape: torch.Size([7313, 1, 500, 1])

# %%
time_data.shape, freq_amp.shape, freq_bins.shape, labels.shape
# Out:
# ((7313, 1, 500, 1), (7313, 1, 250, 1), (7313, 1, 250, 1), (7313,))

# %%
Calc0, freq_data, freq_bins = adapter.get_dictionaries()
# Out:
# Postprocessed data shape: torch.Size([7313, 500, 1]), Original shape: torch.Size([7313, 1, 500, 1])

# %%
freq_bins.keys()
# Out:
# dict_keys(['FFT (N_0)', 'FFT (N_1)', 'FFT (N_2)', 'FFT (N_3)', 'FFT (N_4)', 'FFT (N_5)', 'FFT (N_6)', 'FFT (N_7)', 'FFT (N_8)', 'FFT (N_9)', 'FFT (N_10)', 'FFT (N_11)', 'FFT (N_12)', 'FFT (N_13)', 'FFT (N_14)', 'FFT (N_15)', 'FFT (N_16)', 'FFT (N_17)', 'FFT (N_18)', 'FFT (N_19)', 'FFT (N_20)', 'FFT (N_21)', 'FFT (N_22)', 'FFT (N_23)', 'FFT (N_24)', 'FFT (N_25)', 'FFT (N_26)', 'FFT (N_27)', 'FFT (N_28)', 'FFT (N_29)', 'FFT (N_30)', 'FFT (N_31)', 'FFT (N_32)', 'FFT (N_33)', 'FFT (N_34)', 'FFT (N_35)', 'FFT (N_36)', 'FFT (N_37)', 'FFT (N_38)', 'FFT (N_39)', 'FFT (N_40)', 'FFT (N_41)', 'FFT (N_42)', 'FFT (N_43)', 'FFT (N_44)', 'FFT (N_45)', 'FFT (N_46)', 'FFT (N_47)', 'FFT (N_48)', 'FFT (N_49)', 'FFT (N_50)', 'FFT (N_51)', 'FFT (N_52)', 'FFT (N_53)', 'FFT (N_54)', 'FFT (N_55)', 'FFT (N_56)', 'FFT (N_57)', 'FFT (N_58)', 'FFT (N_59)', 'FFT (N_60)', 'FFT (N_61)', 'FFT (N_62)', 'FFT (N_63)', 'FFT (N_64)', 'FFT (N_65)', 'FFT (N_66)', 'FFT (N_67)', 'FFT (N_68)', 'FFT (N_69)', 'FFT (N_70)', 'FF
# ...
