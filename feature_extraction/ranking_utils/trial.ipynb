# %%
from data_adapter import DataAdapter

adapter = DataAdapter()

time_data, freq_amp, freq_bins, labels = adapter.load_all_data()
# Out:
# Data shape: torch.Size([1900, 1, 500, 1])
# Labels shape: torch.Size([1900])

# %%
time_data.shape, freq_amp.shape, freq_bins.shape, labels.shape
# Out:
# ((1900, 1, 500, 1), (1900, 1, 250, 1), (1900, 1, 250, 1), (1900,))

# %%
import numpy as np

has_complex = np.iscomplexobj(freq_bins)
print(has_complex)
freq_amp
# Out:
# False
# array([[[[1.2383595e-03],
#          [3.3277848e-03],
#          [5.3116479e-03],
#          ...,
#          [1.0150263e-04],
#          [1.0678881e-04],
#          [1.0291146e-04]]],
#
#
#        [[[3.5616532e-02],
#          [5.6362960e-02],
#          [1.1760865e-02],
#          ...,
#          [1.4089241e-04],
#          [1.4506435e-04],
#          [1.4012970e-04]]],
#
#
#        [[[2.5139788e-02],
#          [5.9450120e-02],
#          [5.1879190e-02],
#          ...,
#          [7.7559816e-05],
#          [8.2145605e-05],
#          [9.1756883e-05]]],
#
#
#        ...,
#
#
#        [[[3.3289618e-03],
#          [1.5518455e-02],
#          [1.5322177e-02],
#          ...,
#          [9.9888042e-05],
#          [8.9689260e-05],
#          [9.2523849e-05]]],
#
#
#        [[[9.3440460e-03],
#          [3.7871055e-02],
#          [3.1624909e-02],
#          ...,
#          [1.5997690e-04],
#          [1.5694297e-04],
#          [1.5380127e-04]]],
#
#
# ...

# %%
Calc0, freq_data, freq_bins = adapter.get_dictionaries()
# Out:
# Data shape: torch.Size([1900, 1, 500, 1])
# Labels shape: torch.Size([1900])

# %%
import numpy as np

Calc0.keys()
# Out:
# dict_keys(['N_0', 'N_1', 'N_2', 'N_3', 'N_4', 'N_5', 'N_6', 'N_7', 'N_8', 'N_9', 'N_10', 'N_11', 'N_12', 'N_13', 'N_14', 'N_15', 'N_16', 'N_17', 'N_18', 'N_19', 'N_20', 'N_21', 'N_22', 'N_23', 'N_24', 'N_25', 'N_26', 'N_27', 'N_28', 'N_29', 'N_30', 'N_31', 'N_32', 'N_33', 'N_34', 'N_35', 'N_36', 'N_37', 'N_38', 'N_39', 'N_40', 'N_41', 'N_42', 'N_43', 'N_44', 'N_45', 'N_46', 'N_47', 'N_48', 'N_49', 'N_50', 'N_51', 'N_52', 'N_53', 'N_54', 'N_55', 'N_56', 'N_57', 'N_58', 'N_59', 'N_60', 'N_61', 'N_62', 'N_63', 'N_64', 'N_65', 'N_66', 'N_67', 'N_68', 'N_69', 'N_70', 'N_71', 'N_72', 'N_73', 'N_74', 'N_75', 'N_76', 'N_77', 'N_78', 'N_79', 'N_80', 'N_81', 'N_82', 'N_83', 'N_84', 'N_85', 'N_86', 'N_87', 'N_88', 'N_89', 'N_90', 'N_91', 'N_92', 'N_93', 'N_94', 'N_95', 'N_96', 'N_97', 'N_98', 'N_99', 'N_100', 'N_101', 'N_102', 'N_103', 'N_104', 'N_105', 'N_106', 'N_107', 'N_108', 'N_109', 'N_110', 'N_111', 'N_112', 'N_113', 'N_114', 'N_115', 'N_116', 'N_117', 'N_118', 'N_119', 'N_120', 'N_121',
# ...

# %%
from feature_extraction.config.manager import FeatureRankingConfigMain

rank_config = FeatureRankingConfigMain()

rank_config.get_ranking_log_path(data_config)
# Out:
# 'c:\\Aryan_Savant\\Thesis_Projects\\my_work\\AFD_thesis\\feature_extraction\\logs\\bearing\\cwru\\scene_1\\(gearbox)\\(gearbox)_feature_ranking_1'
